# %%
# config.py

config = {
  "data": {
    "high_dim_path": 'data/MRI_0328.csv',
    "low_dim_path": 'data/ALL.csv',
    "labels_path": 'data/LABEL.csv',
    "brain_region_adjacency_path" : 'data/region_adjacency.csv',
    "batch_size": 256,
    "shuffle": False,
    "test_size":0.01,
    "val_size":0.2,
    "random_state":12345
  },
  "model": {
    "type": "test_high_correlation", # 设置模型跑哪个
    "way_adjmatrix" : "apoe", # 邻接矩阵如何构造
    "high_dim_input_size": 498 ,  
    "low_dim_input_size":17,
    "embedding_dim":128,
    "output_dim":2,
    "hidden_channels":128,
    "num_heads":4 ,
    "num_features":3 # 每个脑区的特征数
      
  },
  "train": {
    "repeat_times" :10, # 简单完成交叉验证的任务
    "epochs": 20,
    "learning_rate": 0.01,
    "device": "cuda:1"
  },
  "earlystopping":{
    "is_on":False,
    "patience":5,
    "delta":0.01
  }
}

# %%
# 集成版本

import torch
import torch.nn as nn
import torch.optim as optim
# import json
from data.data_loader import load_and_align_data, create_data_loader
from models.model import *
from utils import *  # 假设你有评估和早停的辅助函数
from torch_geometric.data import Data          
import torch.optim.lr_scheduler as lr_scheduler
from torch_geometric.utils import dense_to_sparse
#from config import config
import random
import numpy as np
import pandas as pd

# 设置训练设备
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")

# 结果的接收器
random.seed(99)
result = []
repeat_times = config['train']['repeat_times']
random_state = config['data']['random_state']

if repeat_times != 1:
    random_state = [random.randint(0, 10000) for _ in range(config['train']['repeat_times'])]
    print(f'共分割样本{repeat_times}次，随机数种子为：{random_state}')
elif repeat_times == 1:
    random_state = [config['data']['random_state']]
    print(f'仅进行{repeat_times}次分割样本，随机数种子为：{random_state}')
    
brain_adj_matrix = read_brain_region_adjacency(config["data"]["brain_region_adjacency_path"])
brain_edge_index,_ = dense_to_sparse(brain_adj_matrix)

for seed in random_state:
    # 加载数据并创建数据集
    train_dataset, val_dataset, _ = load_and_align_data(high_dim_path = config['data']['high_dim_path'], 
                                                      low_dim_path = config['data']['low_dim_path'],
                                                      labels_path = config['data']['labels_path'],
                                                      test_size = config['data']['test_size'],
                                                      val_size = config['data']['val_size'],
                                                      random_state = seed)
    
    # 创建数据加载器
    train_loader = create_data_loader(train_dataset, batch_size=config['data']['batch_size'], shuffle=config['data']['shuffle'])
    val_loader = create_data_loader(val_dataset, batch_size=config['data']['batch_size'], shuffle=config['data']['shuffle'])
    
    if config['model']['type'] == 'CombinedGAT':
        print(f"Model:{config['model']['type']}")
        model = CombinedGAT(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"],
                     num_heads=config["model"]["num_heads"]).to(device)
    elif config['model']['type'] == 'baseline_MLP':
        print(f"Model:{config['model']['type']}")
        model = baseline_MLP(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'high_low_MLP':
        print(f"Model:{config['model']['type']}")
        model = high_low_MLP(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'only_high_MLP':
        print(f"Model:{config['model']['type']}")
        model = only_high_MLP(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'only_low_MLP':
        print(f"Model:{config['model']['type']}")
        model = only_high_MLP(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'Only_high_GCN':
        print(f"Model:{config['model']['type']}")
        model = Only_high_GCN(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'test_high':
        print(f"Model:{config['model']['type']}")
        model = test_high(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'test_high_correlation':
        print(f"Model:{config['model']['type']}")
        model = test_high_correlation(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'BrainGNN':
        print(f"Model:{config['model']['type']}")
        model = BrainGNN(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"],
                     num_features=config["model"]["num_features"]
                        ).to(device)
    else:
        print(f"Not found Model:{config['model']['type']}")
    
    criterion = nn.NLLLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['train']['learning_rate'])
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=5)
    
    # 初始化早停对象
    early_stopping = EarlyStopping(patience=config["earlystopping"]["patience"], delta=config["earlystopping"]["delta"])
    
    best_val_loss = float('inf')
    
    for epoch in range(config['train']['epochs']):
        model.train()
        total_loss = 0
        correct = 0
        total = 0
        for high_dim_features, low_dim_features, labels in train_loader: 
            batch_size = high_dim_features.size(0)  # 获取当前批次的大小
            
            # 为当前批次生成全连接的邻接矩阵
            if config["model"]["way_adjmatrix"] == 'zero':
                adj_matrix = torch.zeros((batch_size, batch_size))
            elif config["model"]["way_adjmatrix"] == 'only_three':
                adj_matrix = build_adj_matrix_only_three(high_dim_features,low_dim_features,sigma=1)
            elif config["model"]["way_adjmatrix"] == 'similarity_add_three':
                adj_matrix = build_adj_matrix_similarity_add_three(high_dim_features,low_dim_features,sigma=1)
            elif config["model"]["way_adjmatrix"] == 'sex':
                adj_matrix = build_adj_matrix_sex(high_dim_features,low_dim_features,sigma=1)
            elif config["model"]["way_adjmatrix"] == 'apoe':
                adj_matrix = build_adj_matrix_apoe(high_dim_features,low_dim_features,sigma=1)
            elif config["model"]["way_adjmatrix"] == 'mmse':
                adj_matrix = build_adj_matrix_mmse(high_dim_features,low_dim_features,sigma=1)
            edge_index, _ = dense_to_sparse(adj_matrix)
            
            # 准备数据
            high_dim_features = high_dim_features.to(device)
            low_dim_features = low_dim_features.float().to(device)
            labels = labels.to(device)
            
            high_dim_cov_matrix = cov_builder(high_dim_features , labels).to(device)

            brain_edge_index = brain_edge_index.to(device)
    
            # 前向传播
            outputs = model(high_dim_features, low_dim_features, brain_edge_index, high_dim_cov_matrix) #edge_index, high_dim_cov_matrix)
            # outputs = model(high_dim_features, low_dim_features, edge_index, high_dim_cov_matrix)
            loss = criterion(outputs, labels)
    
            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
        train_loss = total_loss / len(train_loader)
        train_acc = 100 * correct / total
    
        # 计算验证集上的损失
        model.eval()
        val_total_loss = 0
        val_correct = 0
        val_total = 0
        val_acc_list = []
    
        with torch.no_grad():
            for high_dim_features, low_dim_features, labels in val_loader: 
                batch_size = high_dim_features.size(0)  # 获取当前批次的大小
                
                # 为当前批次生成全连接的邻接矩阵
                if config["model"]["way_adjmatrix"] == 'zero':
                    adj_matrix = torch.zeros((batch_size, batch_size))
                elif config["model"]["way_adjmatrix"] == 'only_three':
                    adj_matrix = build_adj_matrix_only_three(high_dim_features,low_dim_features,sigma=1)
                elif config["model"]["way_adjmatrix"] == 'similarity_add_three':
                    adj_matrix = build_adj_matrix_similarity_add_three(high_dim_features,low_dim_features,sigma=1)
                elif config["model"]["way_adjmatrix"] == 'sex':
                    adj_matrix = build_adj_matrix_sex(high_dim_features,low_dim_features,sigma=1)
                elif config["model"]["way_adjmatrix"] == 'apoe':
                    adj_matrix = build_adj_matrix_apoe(high_dim_features,low_dim_features,sigma=1)
                elif config["model"]["way_adjmatrix"] == 'mmse':
                    adj_matrix = build_adj_matrix_mmse(high_dim_features,low_dim_features,sigma=1)
                edge_index, _ = dense_to_sparse(adj_matrix)
                    
                high_dim_features = high_dim_features.to(device)
                low_dim_features = low_dim_features.float().to(device)
                labels = labels.to(device)
                edge_index = edge_index.to(device)
                edge_index = edge_index.to(device)
                
                high_dim_cov_matrix = cov_builder(high_dim_features , labels).to(device)
                
                outputs = model(high_dim_features, low_dim_features, brain_edge_index,high_dim_cov_matrix)
                #outputs = model(high_dim_features, low_dim_features, edge_index,high_dim_cov_matrix)

                loss = criterion(outputs, labels)
                val_total_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
                #print(labels.size(0))
                
        val_loss =  val_total_loss/len(val_loader)
        val_acc = 100 * val_correct / val_total
        scheduler.step(val_loss)
        val_acc_list.append(val_acc)
        print(f'Epoch {epoch+1}, Train Loss: {train_loss:.6f}, Train Acc: {train_acc:.6f}, Val Loss: {val_loss:.6f}, Val Acc: {val_acc:.6f}')
        # print(f'Wrong_sample:{val_total-val_correct},Index:{[index for index, (item1, item2) in enumerate(zip(predicted, labels)) if item1 != item2]}')
        # print(predicted)
        
        if config["earlystopping"]["is_on"]:
            early_stopping(val_loss,model)
            if  early_stopping.early_stop:
                print("Early stopping")
                break
                
    result.append(max(val_acc_list))
print(f'Finished! \n Acc:{np.mean(result),max(result)}, \n list:{result}')
# Out:
# 共分割样本10次，随机数种子为：[6618, 6238, 3278, 9821, 2929, 3772, 4070, 2183, 1418, 4114]
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.587317, Train Acc: 66.274510, Val Loss: 8.029654, Val Acc: 54.687500
# Epoch 2, Train Loss: 0.228064, Train Acc: 93.137255, Val Loss: 1.502542, Val Acc: 62.500000
# Epoch 3, Train Loss: 0.161038, Train Acc: 95.490196, Val Loss: 0.954464, Val Acc: 65.625000
# Epoch 4, Train Loss: 0.121179, Train Acc: 96.470588, Val Loss: 1.007545, Val Acc: 70.312500
# Epoch 5, Train Loss: 0.092118, Train Acc: 97.450980, Val Loss: 0.458698, Val Acc: 82.812500
# Epoch 6, Train Loss: 0.067679, Train Acc: 97.647059, Val Loss: 0.367074, Val Acc: 87.500000
# Epoch 7, Train Loss: 0.053842, Train Acc: 98.235294, Val Loss: 0.214916, Val Acc: 92.187500
# Epoch 8, Train Loss: 0.041913, Train Acc: 98.627451, Val Loss: 0.179400, Val Acc: 93.750000
# Epoch 9, Train Loss: 0.034478, Train Acc: 98.823529, Val Loss: 0.230544, Val Acc: 90.625000
# Epoch 10, Train Loss: 0.025052, Train Acc: 99.215686, Val Loss: 0.262041, Val Acc: 92.968750
# Epoch 11, Train Loss: 0.015543, Train Acc: 100.000000, Val Loss: 0.297721, Val Acc: 93.750000
# Epoch 12, Train Loss: 0.010240, Train Acc: 100.000000, Val Loss: 0.286687, Val Acc: 91.406250
# Epoch 13, Train Loss: 0.009103, Train Acc: 100.000000, Val Loss: 0.295765, Val Acc: 90.625000
# Epoch 14, Train Loss: 0.006609, Train Acc: 100.000000, Val Loss: 0.311467, Val Acc: 92.968750
# Epoch 15, Train Loss: 0.004068, Train Acc: 100.000000, Val Loss: 0.331638, Val Acc: 92.187500
# Epoch 16, Train Loss: 0.003262, Train Acc: 100.000000, Val Loss: 0.304962, Val Acc: 92.187500
# Epoch 17, Train Loss: 0.002704, Train Acc: 100.000000, Val Loss: 0.281984, Val Acc: 90.625000
# Epoch 18, Train Loss: 0.002357, Train Acc: 100.000000, Val Loss: 0.347580, Val Acc: 89.843750
# Epoch 19, Train Loss: 0.002867, Train Acc: 100.000000, Val Loss: 0.359307, Val Acc: 91.406250
# Epoch 20, Train Loss: 0.002750, Train Acc: 100.000000, Val Loss: 0.332722, Val Acc: 89.062500
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.535451, Train Acc: 66.078431, Val Loss: 2.831754, Val Acc: 54.687500
# Epoch 2, Train Loss: 0.219183, Train Acc: 90.980392, Val Loss: 2.862091, Val Acc: 64.843750
# Epoch 3, Train Loss: 0.137078, Train Acc: 95.490196, Val Loss: 0.298651, Val Acc: 89.062500
# Epoch 4, Train Loss: 0.108604, Train Acc: 96.862745, Val Loss: 0.423776, Val Acc: 85.937500
# Epoch 5, Train Loss: 0.078425, Train Acc: 97.843137, Val Loss: 0.695134, Val Acc: 82.812500
# Epoch 6, Train Loss: 0.065634, Train Acc: 97.058824, Val Loss: 0.944691, Val Acc: 77.343750
# Epoch 7, Train Loss: 0.044508, Train Acc: 98.431373, Val Loss: 0.819699, Val Acc: 78.125000
# Epoch 8, Train Loss: 0.031612, Train Acc: 99.411765, Val Loss: 0.806934, Val Acc: 79.687500
# Epoch 9, Train Loss: 0.024077, Train Acc: 99.411765, Val Loss: 0.717814, Val Acc: 82.031250
# Epoch 10, Train Loss: 0.016768, Train Acc: 100.000000, Val Loss: 0.622417, Val Acc: 84.375000
# Epoch 11, Train Loss: 0.016416, Train Acc: 100.000000, Val Loss: 0.718209, Val Acc: 83.593750
# Epoch 12, Train Loss: 0.010618, Train Acc: 100.000000, Val Loss: inf, Val Acc: 85.156250
# Epoch 13, Train Loss: 0.012361, Train Acc: 100.000000, Val Loss: inf, Val Acc: 83.593750
# Epoch 14, Train Loss: 0.010709, Train Acc: 100.000000, Val Loss: inf, Val Acc: 88.281250
# Epoch 15, Train Loss: 0.007402, Train Acc: 100.000000, Val Loss: inf, Val Acc: 89.062500
# Epoch 16, Train Loss: 0.008961, Train Acc: 100.000000, Val Loss: inf, Val Acc: 88.281250
# Epoch 17, Train Loss: 0.009342, Train Acc: 100.000000, Val Loss: 0.424549, Val Acc: 89.062500
# Epoch 18, Train Loss: 0.005434, Train Acc: 100.000000, Val Loss: inf, Val Acc: 90.625000
# Epoch 19, Train Loss: 0.006901, Train Acc: 100.000000, Val Loss: inf, Val Acc: 89.843750
# Epoch 20, Train Loss: 0.007963, Train Acc: 100.000000, Val Loss: 0.376647, Val Acc: 89.843750
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.579515, Train Acc: 68.431373, Val Loss: 3.582540, Val Acc: 48.437500
# Epoch 2, Train Loss: 0.225971, Train Acc: 90.980392, Val Loss: 6.994970, Val Acc: 55.468750
# Epoch 3, Train Loss: 0.145312, Train Acc: 96.274510, Val Loss: 0.408256, Val Acc: 81.250000
# Epoch 4, Train Loss: 0.108468, Train Acc: 96.862745, Val Loss: 0.351897, Val Acc: 85.156250
# Epoch 5, Train Loss: 0.083447, Train Acc: 97.450980, Val Loss: 0.481242, Val Acc: 83.593750
# Epoch 6, Train Loss: 0.057941, Train Acc: 98.235294, Val Loss: 0.523641, Val Acc: 85.156250
# Epoch 7, Train Loss: 0.042618, Train Acc: 98.823529, Val Loss: 0.550179, Val Acc: 86.718750
# Epoch 8, Train Loss: 0.027924, Train Acc: 99.411765, Val Loss: 0.466465, Val Acc: 85.156250
# Epoch 9, Train Loss: 0.020954, Train Acc: 99.607843, Val Loss: 0.451868, Val Acc: 87.500000
# Epoch 10, Train Loss: 0.014858, Train Acc: 99.607843, Val Loss: 0.519177, Val Acc: 87.500000
# Epoch 11, Train Loss: 0.012658, Train Acc: 99.803922, Val Loss: 0.484854, Val Acc: 90.625000
# Epoch 12, Train Loss: 0.008213, Train Acc: 100.000000, Val Loss: 0.546466, Val Acc: 90.625000
# Epoch 13, Train Loss: 0.006363, Train Acc: 100.000000, Val Loss: 0.583049, Val Acc: 89.843750
# Epoch 14, Train Loss: 0.005668, Train Acc: 100.000000, Val Loss: 0.564757, Val Acc: 89.843750
# Epoch 15, Train Loss: 0.008244, Train Acc: 100.000000, Val Loss: 0.610253, Val Acc: 90.625000
# Epoch 16, Train Loss: 0.004633, Train Acc: 100.000000, Val Loss: 0.678368, Val Acc: 90.625000
# Epoch 17, Train Loss: 0.004542, Train Acc: 100.000000, Val Loss: 0.809240, Val Acc: 88.281250
# Epoch 18, Train Loss: 0.004661, Train Acc: 100.000000, Val Loss: 0.791911, Val Acc: 89.843750
# Epoch 19, Train Loss: 0.004601, Train Acc: 100.000000, Val Loss: 0.971205, Val Acc: 87.500000
# Epoch 20, Train Loss: 0.005573, Train Acc: 100.000000, Val Loss: 1.050493, Val Acc: 87.500000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.500589, Train Acc: 70.784314, Val Loss: 6.104963, Val Acc: 57.812500
# Epoch 2, Train Loss: 0.187687, Train Acc: 94.117647, Val Loss: 5.947525, Val Acc: 51.562500
# Epoch 3, Train Loss: 0.124397, Train Acc: 96.470588, Val Loss: 0.545558, Val Acc: 75.781250
# Epoch 4, Train Loss: 0.089826, Train Acc: 97.450980, Val Loss: 0.307542, Val Acc: 89.843750
# Epoch 5, Train Loss: 0.071637, Train Acc: 98.235294, Val Loss: 0.251572, Val Acc: 92.968750
# Epoch 6, Train Loss: 0.048903, Train Acc: 98.627451, Val Loss: inf, Val Acc: 54.687500
# Epoch 7, Train Loss: 0.033745, Train Acc: 98.823529, Val Loss: 0.619636, Val Acc: 85.937500
# Epoch 8, Train Loss: 0.026487, Train Acc: 99.215686, Val Loss: 0.313081, Val Acc: 90.625000
# Epoch 9, Train Loss: 0.017542, Train Acc: 99.803922, Val Loss: 0.313867, Val Acc: 90.625000
# Epoch 10, Train Loss: 0.012379, Train Acc: 100.000000, Val Loss: 0.370541, Val Acc: 90.625000
# Epoch 11, Train Loss: 0.009797, Train Acc: 99.803922, Val Loss: 0.363361, Val Acc: 90.625000
# Epoch 12, Train Loss: 0.005848, Train Acc: 100.000000, Val Loss: 0.311084, Val Acc: 90.625000
# Epoch 13, Train Loss: 0.005390, Train Acc: 100.000000, Val Loss: 0.381959, Val Acc: 90.625000
# Epoch 14, Train Loss: 0.004600, Train Acc: 100.000000, Val Loss: 0.404891, Val Acc: 90.625000
# Epoch 15, Train Loss: 0.003245, Train Acc: 100.000000, Val Loss: 0.409854, Val Acc: 89.843750
# Epoch 16, Train Loss: 0.003040, Train Acc: 100.000000, Val Loss: 0.434014, Val Acc: 90.625000
# Epoch 17, Train Loss: 0.004917, Train Acc: 100.000000, Val Loss: 0.462919, Val Acc: 90.625000
# Epoch 18, Train Loss: 0.003187, Train Acc: 100.000000, Val Loss: 0.418507, Val Acc: 89.843750
# Epoch 19, Train Loss: 0.003376, Train Acc: 100.000000, Val Loss: 0.401896, Val Acc: 91.406250
# Epoch 20, Train Loss: 0.003233, Train Acc: 100.000000, Val Loss: 0.387591, Val Acc: 91.406250
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.515307, Train Acc: 70.784314, Val Loss: inf, Val Acc: 53.906250
# Epoch 2, Train Loss: 0.211549, Train Acc: 91.176471, Val Loss: 0.583385, Val Acc: 72.656250
# Epoch 3, Train Loss: 0.135466, Train Acc: 95.882353, Val Loss: 0.541137, Val Acc: 78.125000
# Epoch 4, Train Loss: 0.095496, Train Acc: 98.039216, Val Loss: 0.421907, Val Acc: 81.250000
# Epoch 5, Train Loss: 0.069183, Train Acc: 98.235294, Val Loss: 0.569661, Val Acc: 79.687500
# Epoch 6, Train Loss: 0.049565, Train Acc: 98.431373, Val Loss: 0.537644, Val Acc: 83.593750
# Epoch 7, Train Loss: 0.028880, Train Acc: 99.215686, Val Loss: 0.553506, Val Acc: 82.031250
# Epoch 8, Train Loss: 0.025249, Train Acc: 99.019608, Val Loss: 0.641465, Val Acc: 81.250000
# Epoch 9, Train Loss: 0.019855, Train Acc: 99.803922, Val Loss: 0.761657, Val Acc: 79.687500
# Epoch 10, Train Loss: 0.015430, Train Acc: 99.411765, Val Loss: 0.917653, Val Acc: 79.687500
# Epoch 11, Train Loss: 0.009217, Train Acc: 100.000000, Val Loss: 0.686150, Val Acc: 82.812500
# Epoch 12, Train Loss: 0.007138, Train Acc: 100.000000, Val Loss: 0.818314, Val Acc: 82.812500
# Epoch 13, Train Loss: 0.005442, Train Acc: 100.000000, Val Loss: 0.792306, Val Acc: 82.812500
# Epoch 14, Train Loss: 0.007605, Train Acc: 99.803922, Val Loss: 0.769643, Val Acc: 82.031250
# Epoch 15, Train Loss: 0.004980, Train Acc: 100.000000, Val Loss: 0.827179, Val Acc: 83.593750
# Epoch 16, Train Loss: 0.005011, Train Acc: 100.000000, Val Loss: 0.905105, Val Acc: 82.812500
# Epoch 17, Train Loss: 0.004346, Train Acc: 100.000000, Val Loss: 0.993497, Val Acc: 82.031250
# Epoch 18, Train Loss: 0.004076, Train Acc: 100.000000, Val Loss: 1.175571, Val Acc: 82.031250
# Epoch 19, Train Loss: 0.005842, Train Acc: 100.000000, Val Loss: 1.384834, Val Acc: 80.468750
# Epoch 20, Train Loss: 0.004259, Train Acc: 100.000000, Val Loss: 1.261023, Val Acc: 84.375000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.518193, Train Acc: 70.392157, Val Loss: 12.588949, Val Acc: 48.437500
# Epoch 2, Train Loss: 0.199934, Train Acc: 92.549020, Val Loss: 5.083632, Val Acc: 62.500000
# Epoch 3, Train Loss: 0.136657, Train Acc: 95.686275, Val Loss: 2.508441, Val Acc: 78.125000
# Epoch 4, Train Loss: 0.105746, Train Acc: 96.666667, Val Loss: 0.276119, Val Acc: 88.281250
# Epoch 5, Train Loss: 0.080699, Train Acc: 97.450980, Val Loss: 0.312163, Val Acc: 89.062500
# Epoch 6, Train Loss: 0.058491, Train Acc: 98.235294, Val Loss: 0.447216, Val Acc: 84.375000
# Epoch 7, Train Loss: 0.042048, Train Acc: 99.019608, Val Loss: 0.315211, Val Acc: 87.500000
# Epoch 8, Train Loss: 0.031083, Train Acc: 99.215686, Val Loss: inf, Val Acc: 53.906250
# Epoch 9, Train Loss: 0.020442, Train Acc: 99.607843, Val Loss: 0.231477, Val Acc: 89.843750
# Epoch 10, Train Loss: 0.014508, Train Acc: 100.000000, Val Loss: 0.224093, Val Acc: 91.406250
# Epoch 11, Train Loss: 0.011753, Train Acc: 100.000000, Val Loss: 0.244768, Val Acc: 93.750000
# Epoch 12, Train Loss: 0.009558, Train Acc: 99.803922, Val Loss: 0.325117, Val Acc: 87.500000
# Epoch 13, Train Loss: 0.005810, Train Acc: 100.000000, Val Loss: 0.385690, Val Acc: 90.625000
# Epoch 14, Train Loss: 0.004228, Train Acc: 100.000000, Val Loss: 0.438764, Val Acc: 87.500000
# Epoch 15, Train Loss: 0.003636, Train Acc: 100.000000, Val Loss: 0.344297, Val Acc: 90.625000
# Epoch 16, Train Loss: 0.003185, Train Acc: 100.000000, Val Loss: 0.382757, Val Acc: 87.500000
# Epoch 17, Train Loss: 0.001912, Train Acc: 100.000000, Val Loss: 0.372709, Val Acc: 90.625000
# Epoch 18, Train Loss: 0.002035, Train Acc: 100.000000, Val Loss: 0.445708, Val Acc: 89.062500
# Epoch 19, Train Loss: 0.002165, Train Acc: 100.000000, Val Loss: 0.423507, Val Acc: 89.062500
# Epoch 20, Train Loss: 0.001615, Train Acc: 100.000000, Val Loss: 0.401435, Val Acc: 91.406250
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.599359, Train Acc: 68.627451, Val Loss: 6.360045, Val Acc: 55.468750
# Epoch 2, Train Loss: 0.253740, Train Acc: 89.019608, Val Loss: 0.670657, Val Acc: 76.562500
# Epoch 3, Train Loss: 0.175940, Train Acc: 95.098039, Val Loss: 1.606121, Val Acc: 68.750000
# Epoch 4, Train Loss: 0.143417, Train Acc: 95.098039, Val Loss: 1.137840, Val Acc: 77.343750
# Epoch 5, Train Loss: 0.106368, Train Acc: 96.470588, Val Loss: 0.398805, Val Acc: 85.937500
# Epoch 6, Train Loss: 0.076474, Train Acc: 97.647059, Val Loss: 0.294364, Val Acc: 88.281250
# Epoch 7, Train Loss: 0.061733, Train Acc: 98.039216, Val Loss: inf, Val Acc: 59.375000
# Epoch 8, Train Loss: 0.039205, Train Acc: 99.215686, Val Loss: 0.359227, Val Acc: 86.718750
# Epoch 9, Train Loss: 0.033738, Train Acc: 99.019608, Val Loss: inf, Val Acc: 56.250000
# Epoch 10, Train Loss: 0.023995, Train Acc: 99.607843, Val Loss: 0.296592, Val Acc: 89.843750
# Epoch 11, Train Loss: 0.016547, Train Acc: 100.000000, Val Loss: 0.204407, Val Acc: 91.406250
# Epoch 12, Train Loss: 0.010501, Train Acc: 100.000000, Val Loss: 0.219867, Val Acc: 93.750000
# Epoch 13, Train Loss: 0.011316, Train Acc: 100.000000, Val Loss: 0.242454, Val Acc: 92.968750
# Epoch 14, Train Loss: 0.006504, Train Acc: 100.000000, Val Loss: 0.287680, Val Acc: 92.968750
# Epoch 15, Train Loss: 0.005827, Train Acc: 100.000000, Val Loss: 0.337909, Val Acc: 90.625000
# Epoch 16, Train Loss: 0.004046, Train Acc: 100.000000, Val Loss: 0.348797, Val Acc: 89.843750
# Epoch 17, Train Loss: 0.002844, Train Acc: 100.000000, Val Loss: 0.371996, Val Acc: 92.187500
# Epoch 18, Train Loss: 0.002611, Train Acc: 100.000000, Val Loss: 0.375970, Val Acc: 92.187500
# Epoch 19, Train Loss: 0.001960, Train Acc: 100.000000, Val Loss: 0.491917, Val Acc: 90.625000
# Epoch 20, Train Loss: 0.001656, Train Acc: 100.000000, Val Loss: 0.410274, Val Acc: 90.625000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.517932, Train Acc: 70.784314, Val Loss: inf, Val Acc: 53.125000
# Epoch 2, Train Loss: 0.208513, Train Acc: 92.156863, Val Loss: 0.519725, Val Acc: 83.593750
# Epoch 3, Train Loss: 0.152901, Train Acc: 95.098039, Val Loss: 1.624309, Val Acc: 71.875000
# Epoch 4, Train Loss: 0.117879, Train Acc: 95.686275, Val Loss: 0.756023, Val Acc: 88.281250
# Epoch 5, Train Loss: 0.086482, Train Acc: 97.450980, Val Loss: 0.378831, Val Acc: 90.625000
# Epoch 6, Train Loss: 0.059801, Train Acc: 98.431373, Val Loss: 0.448742, Val Acc: 90.625000
# Epoch 7, Train Loss: 0.049181, Train Acc: 97.843137, Val Loss: 0.592141, Val Acc: 90.625000
# Epoch 8, Train Loss: 0.034374, Train Acc: 99.215686, Val Loss: 0.638350, Val Acc: 89.062500
# Epoch 9, Train Loss: 0.021578, Train Acc: 99.607843, Val Loss: 0.489600, Val Acc: 90.625000
# Epoch 10, Train Loss: 0.015653, Train Acc: 99.803922, Val Loss: 0.779077, Val Acc: 89.062500
# Epoch 11, Train Loss: 0.010067, Train Acc: 100.000000, Val Loss: 0.783515, Val Acc: 89.843750
# Epoch 12, Train Loss: 0.009797, Train Acc: 100.000000, Val Loss: 0.759392, Val Acc: 88.281250
# Epoch 13, Train Loss: 0.006972, Train Acc: 100.000000, Val Loss: 1.075346, Val Acc: 87.500000
# Epoch 14, Train Loss: 0.006226, Train Acc: 100.000000, Val Loss: 1.161702, Val Acc: 89.062500
# Epoch 15, Train Loss: 0.006351, Train Acc: 100.000000, Val Loss: 1.276010, Val Acc: 89.062500
# Epoch 16, Train Loss: 0.005087, Train Acc: 100.000000, Val Loss: 1.356060, Val Acc: 88.281250
# Epoch 17, Train Loss: 0.003745, Train Acc: 100.000000, Val Loss: 1.650992, Val Acc: 85.156250
# Epoch 18, Train Loss: 0.003270, Train Acc: 100.000000, Val Loss: 2.196300, Val Acc: 82.031250
# Epoch 19, Train Loss: 0.003433, Train Acc: 100.000000, Val Loss: 3.054709, Val Acc: 77.343750
# Epoch 20, Train Loss: 0.005069, Train Acc: 100.000000, Val Loss: inf, Val Acc: 76.562500
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.507160, Train Acc: 71.960784, Val Loss: 7.659811, Val Acc: 47.656250
# Epoch 2, Train Loss: 0.215311, Train Acc: 92.352941, Val Loss: 6.271785, Val Acc: 55.468750
# Epoch 3, Train Loss: 0.152394, Train Acc: 94.705882, Val Loss: 3.118752, Val Acc: 57.812500
# Epoch 4, Train Loss: 0.097463, Train Acc: 97.450980, Val Loss: 3.411520, Val Acc: 59.375000
# Epoch 5, Train Loss: 0.063566, Train Acc: 98.823529, Val Loss: 3.225943, Val Acc: 62.500000
# Epoch 6, Train Loss: 0.046355, Train Acc: 99.607843, Val Loss: 2.578338, Val Acc: 64.062500
# Epoch 7, Train Loss: 0.032762, Train Acc: 99.607843, Val Loss: 2.014183, Val Acc: 72.656250
# Epoch 8, Train Loss: 0.020748, Train Acc: 99.803922, Val Loss: 1.579728, Val Acc: 78.125000
# Epoch 9, Train Loss: 0.014657, Train Acc: 99.803922, Val Loss: 1.305392, Val Acc: 78.906250
# Epoch 10, Train Loss: 0.008546, Train Acc: 100.000000, Val Loss: 1.102883, Val Acc: 80.468750
# Epoch 11, Train Loss: 0.005904, Train Acc: 100.000000, Val Loss: 1.033804, Val Acc: 83.593750
# Epoch 12, Train Loss: 0.003553, Train Acc: 100.000000, Val Loss: 1.099296, Val Acc: 82.031250
# Epoch 13, Train Loss: 0.003577, Train Acc: 100.000000, Val Loss: 1.101630, Val Acc: 84.375000
# Epoch 14, Train Loss: 0.003007, Train Acc: 100.000000, Val Loss: 0.970428, Val Acc: 86.718750
# Epoch 15, Train Loss: 0.002268, Train Acc: 100.000000, Val Loss: 1.014781, Val Acc: 88.281250
# Epoch 16, Train Loss: 0.002934, Train Acc: 100.000000, Val Loss: 1.042083, Val Acc: 88.281250
# Epoch 17, Train Loss: 0.001234, Train Acc: 100.000000, Val Loss: 1.003604, Val Acc: 89.062500
# Epoch 18, Train Loss: 0.001272, Train Acc: 100.000000, Val Loss: 1.272224, Val Acc: 85.937500
# Epoch 19, Train Loss: 0.000810, Train Acc: 100.000000, Val Loss: 1.358750, Val Acc: 87.500000
# Epoch 20, Train Loss: 0.000536, Train Acc: 100.000000, Val Loss: 1.655958, Val Acc: 84.375000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.587003, Train Acc: 64.901961, Val Loss: 5.259845, Val Acc: 59.375000
# Epoch 2, Train Loss: 0.194021, Train Acc: 93.137255, Val Loss: 0.373051, Val Acc: 87.500000
# Epoch 3, Train Loss: 0.136931, Train Acc: 95.098039, Val Loss: 0.256490, Val Acc: 90.625000
# Epoch 4, Train Loss: 0.106670, Train Acc: 97.450980, Val Loss: inf, Val Acc: 53.906250
# Epoch 5, Train Loss: 0.080434, Train Acc: 97.843137, Val Loss: 0.486732, Val Acc: 87.500000
# Epoch 6, Train Loss: 0.064339, Train Acc: 98.235294, Val Loss: 0.259853, Val Acc: 93.750000
# Epoch 7, Train Loss: 0.047999, Train Acc: 98.431373, Val Loss: 0.281976, Val Acc: 92.187500
# Epoch 8, Train Loss: 0.032724, Train Acc: 99.215686, Val Loss: 0.250900, Val Acc: 92.187500
# Epoch 9, Train Loss: 0.018385, Train Acc: 99.803922, Val Loss: 0.296808, Val Acc: 90.625000
# Epoch 10, Train Loss: 0.013701, Train Acc: 99.803922, Val Loss: 0.328175, Val Acc: 92.968750
# Epoch 11, Train Loss: 0.009209, Train Acc: 100.000000, Val Loss: 0.403888, Val Acc: 92.187500
# Epoch 12, Train Loss: 0.009972, Train Acc: 99.803922, Val Loss: 0.555803, Val Acc: 92.187500
# Epoch 13, Train Loss: 0.005210, Train Acc: 100.000000, Val Loss: 0.468480, Val Acc: 92.968750
# Epoch 14, Train Loss: 0.004624, Train Acc: 100.000000, Val Loss: 0.558136, Val Acc: 92.968750
# Epoch 15, Train Loss: 0.003376, Train Acc: 100.000000, Val Loss: 0.416864, Val Acc: 91.406250
# Epoch 16, Train Loss: 0.003307, Train Acc: 100.000000, Val Loss: 0.415884, Val Acc: 90.625000
# Epoch 17, Train Loss: 0.001354, Train Acc: 100.000000, Val Loss: 0.494884, Val Acc: 90.625000
# Epoch 18, Train Loss: 0.002081, Train Acc: 100.000000, Val Loss: 0.405554, Val Acc: 89.843750
# Epoch 19, Train Loss: 0.001815, Train Acc: 100.000000, Val Loss: 0.544347, Val Acc: 87.500000
# Epoch 20, Train Loss: 0.002105, Train Acc: 100.000000, Val Loss: 0.454851, Val Acc: 89.843750
# Finished!
#  Acc:(87.5, 91.40625),
#  list:[89.0625, 89.84375, 87.5, 91.40625, 84.375, 91.40625, 90.625, 76.5625, 84.375, 89.84375]

# %%
np.mean([89.0625, 89.84375, 87.5, 91.40625, 84.375, 91.40625, 90.625, 76.5625, 84.375, 89.84375])
# Out:
# 87.5

# %%
# config.py

config = {
  "data": {
    "high_dim_path": 'data/MRI_0328.csv',
    "low_dim_path": 'data/ALL.csv',
    "labels_path": 'data/LABEL.csv',
    "brain_region_adjacency_path" : 'data/region_adjacency.csv',
    "batch_size": 256,
    "shuffle": False,
    "test_size":0.01,
    "val_size":0.2,
    "random_state":12345
  },
  "model": {
    "type": "test_high_correlation", # 设置模型跑哪个
    "way_adjmatrix" : "apoe", # 邻接矩阵如何构造
    "high_dim_input_size": 498 ,  
    "low_dim_input_size":17,
    "embedding_dim":128,
    "output_dim":2,
    "hidden_channels":128,
    "num_heads":4 ,
    "num_features":3 # 每个脑区的特征数
      
  },
  "train": {
    "repeat_times" :10, # 简单完成交叉验证的任务
    "epochs": 20,
    "learning_rate": 0.01,
    "device": "cuda:1"
  },
  "earlystopping":{
    "is_on":False,
    "patience":5,
    "delta":0.01
  }
}

# %%
# 集成版本

import torch
import torch.nn as nn
import torch.optim as optim
# import json
from data.data_loader import load_and_align_data, create_data_loader
from models.model import *
from utils import *  # 假设你有评估和早停的辅助函数
from torch_geometric.data import Data          
import torch.optim.lr_scheduler as lr_scheduler
from torch_geometric.utils import dense_to_sparse
#from config import config
import random
import numpy as np
import pandas as pd

# 设置训练设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")

# 结果的接收器
random.seed(99)
result = []
repeat_times = config['train']['repeat_times']
random_state = config['data']['random_state']

if repeat_times != 1:
    random_state = [random.randint(0, 10000) for _ in range(config['train']['repeat_times'])]
    print(f'共分割样本{repeat_times}次，随机数种子为：{random_state}')
elif repeat_times == 1:
    random_state = [config['data']['random_state']]
    print(f'仅进行{repeat_times}次分割样本，随机数种子为：{random_state}')
    
brain_adj_matrix = read_brain_region_adjacency(config["data"]["brain_region_adjacency_path"])
brain_edge_index,_ = dense_to_sparse(brain_adj_matrix)

for seed in random_state:
    # 加载数据并创建数据集
    train_dataset, val_dataset, _ = load_and_align_data(high_dim_path = config['data']['high_dim_path'], 
                                                      low_dim_path = config['data']['low_dim_path'],
                                                      labels_path = config['data']['labels_path'],
                                                      test_size = config['data']['test_size'],
                                                      val_size = config['data']['val_size'],
                                                      random_state = seed)
    
    # 创建数据加载器
    train_loader = create_data_loader(train_dataset, batch_size=config['data']['batch_size'], shuffle=config['data']['shuffle'])
    val_loader = create_data_loader(val_dataset, batch_size=config['data']['batch_size'], shuffle=config['data']['shuffle'])
    
    if config['model']['type'] == 'CombinedGAT':
        print(f"Model:{config['model']['type']}")
        model = CombinedGAT(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"],
                     num_heads=config["model"]["num_heads"]).to(device)
    elif config['model']['type'] == 'baseline_MLP':
        print(f"Model:{config['model']['type']}")
        model = baseline_MLP(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'high_low_MLP':
        print(f"Model:{config['model']['type']}")
        model = high_low_MLP(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'only_high_MLP':
        print(f"Model:{config['model']['type']}")
        model = only_high_MLP(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'only_low_MLP':
        print(f"Model:{config['model']['type']}")
        model = only_high_MLP(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'Only_high_GCN':
        print(f"Model:{config['model']['type']}")
        model = Only_high_GCN(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'test_high':
        print(f"Model:{config['model']['type']}")
        model = test_high(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'test_high_correlation':
        print(f"Model:{config['model']['type']}")
        model = test_high_correlation(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"]).to(device)
    elif config['model']['type'] == 'BrainGNN':
        print(f"Model:{config['model']['type']}")
        model = BrainGNN(high_dim_input_size=config["model"]["high_dim_input_size"],  # 适当调整这些参数，这里可以写成config
                     low_dim_input_size=config["model"]["low_dim_input_size"],
                     embedding_dim=config["model"]["embedding_dim"],
                     output_dim=config["model"]["output_dim"],  # 根据您的任务调整
                     hidden_channels=config["model"]["hidden_channels"],
                     num_features=config["model"]["num_features"]
                        ).to(device)
    else:
        print(f"Not found Model:{config['model']['type']}")
    
    criterion = nn.NLLLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['train']['learning_rate'])
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=5)
    
    # 初始化早停对象
    early_stopping = EarlyStopping(patience=config["earlystopping"]["patience"], delta=config["earlystopping"]["delta"])
    
    best_val_loss = float('inf')
    
    for epoch in range(config['train']['epochs']):
        model.train()
        total_loss = 0
        correct = 0
        total = 0
        for high_dim_features, low_dim_features, labels in train_loader: 
            batch_size = high_dim_features.size(0)  # 获取当前批次的大小
            
            # 为当前批次生成全连接的邻接矩阵
            if config["model"]["way_adjmatrix"] == 'zero':
                adj_matrix = torch.zeros((batch_size, batch_size))
            elif config["model"]["way_adjmatrix"] == 'only_three':
                adj_matrix = build_adj_matrix_only_three(high_dim_features,low_dim_features,sigma=1)
            elif config["model"]["way_adjmatrix"] == 'similarity_add_three':
                adj_matrix = build_adj_matrix_similarity_add_three(high_dim_features,low_dim_features,sigma=1)
            elif config["model"]["way_adjmatrix"] == 'sex':
                adj_matrix = build_adj_matrix_sex(high_dim_features,low_dim_features,sigma=1)
            elif config["model"]["way_adjmatrix"] == 'apoe':
                adj_matrix = build_adj_matrix_apoe(high_dim_features,low_dim_features,sigma=1)
            elif config["model"]["way_adjmatrix"] == 'mmse':
                adj_matrix = build_adj_matrix_mmse(high_dim_features,low_dim_features,sigma=1)
            edge_index, _ = dense_to_sparse(adj_matrix)
            
            # 准备数据
            high_dim_features = high_dim_features.to(device)
            low_dim_features = low_dim_features.float().to(device)
            labels = labels.to(device)
            
            high_dim_cov_matrix = cov_builder(high_dim_features , labels).to(device)

            brain_edge_index = brain_edge_index.to(device)
    
            # 前向传播
            outputs = model(high_dim_features, low_dim_features, brain_edge_index, high_dim_cov_matrix) #edge_index, high_dim_cov_matrix)
            # outputs = model(high_dim_features, low_dim_features, edge_index, high_dim_cov_matrix)
            loss = criterion(outputs, labels)
    
            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
        train_loss = total_loss / len(train_loader)
        train_acc = 100 * correct / total
    
        # 计算验证集上的损失
        model.eval()
        val_total_loss = 0
        val_correct = 0
        val_total = 0
        val_acc_list = []
    
        with torch.no_grad():
            for high_dim_features, low_dim_features, labels in val_loader: 
                batch_size = high_dim_features.size(0)  # 获取当前批次的大小
                
                # 为当前批次生成全连接的邻接矩阵
                if config["model"]["way_adjmatrix"] == 'zero':
                    adj_matrix = torch.zeros((batch_size, batch_size))
                elif config["model"]["way_adjmatrix"] == 'only_three':
                    adj_matrix = build_adj_matrix_only_three(high_dim_features,low_dim_features,sigma=1)
                elif config["model"]["way_adjmatrix"] == 'similarity_add_three':
                    adj_matrix = build_adj_matrix_similarity_add_three(high_dim_features,low_dim_features,sigma=1)
                elif config["model"]["way_adjmatrix"] == 'sex':
                    adj_matrix = build_adj_matrix_sex(high_dim_features,low_dim_features,sigma=1)
                elif config["model"]["way_adjmatrix"] == 'apoe':
                    adj_matrix = build_adj_matrix_apoe(high_dim_features,low_dim_features,sigma=1)
                elif config["model"]["way_adjmatrix"] == 'mmse':
                    adj_matrix = build_adj_matrix_mmse(high_dim_features,low_dim_features,sigma=1)
                edge_index, _ = dense_to_sparse(adj_matrix)
                    
                high_dim_features = high_dim_features.to(device)
                low_dim_features = low_dim_features.float().to(device)
                labels = labels.to(device)
                edge_index = edge_index.to(device)
                edge_index = edge_index.to(device)
                
                high_dim_cov_matrix = cov_builder(high_dim_features , labels).to(device)
                
                outputs = model(high_dim_features, low_dim_features, brain_edge_index,high_dim_cov_matrix)
                #outputs = model(high_dim_features, low_dim_features, edge_index,high_dim_cov_matrix)

                loss = criterion(outputs, labels)
                val_total_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
                #print(labels.size(0))
                
        val_loss =  val_total_loss/len(val_loader)
        val_acc = 100 * val_correct / val_total
        scheduler.step(val_loss)
        val_acc_list.append(val_acc)
        print(f'Epoch {epoch+1}, Train Loss: {train_loss:.6f}, Train Acc: {train_acc:.6f}, Val Loss: {val_loss:.6f}, Val Acc: {val_acc:.6f}')
        # print(f'Wrong_sample:{val_total-val_correct},Index:{[index for index, (item1, item2) in enumerate(zip(predicted, labels)) if item1 != item2]}')
        # print(predicted)
        
        if config["earlystopping"]["is_on"]:
            early_stopping(val_loss,model)
            if  early_stopping.early_stop:
                print("Early stopping")
                break
                
    result.append(max(val_acc_list))
print(f'Finished! \n Acc:{np.mean(result),max(result)}, \n list:{result}')
# Out:
# 共分割样本10次，随机数种子为：[6618, 6238, 3278, 9821, 2929, 3772, 4070, 2183, 1418, 4114]
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.428569, Train Acc: 73.967459, Val Loss: inf, Val Acc: 64.000000
# Epoch 2, Train Loss: 0.200421, Train Acc: 90.237797, Val Loss: inf, Val Acc: 75.000000
# Epoch 3, Train Loss: 0.123231, Train Acc: 95.369212, Val Loss: inf, Val Acc: 73.500000
# Epoch 4, Train Loss: 0.073284, Train Acc: 96.745932, Val Loss: 2.476423, Val Acc: 83.000000
# Epoch 5, Train Loss: 0.053642, Train Acc: 97.747184, Val Loss: 1.568280, Val Acc: 87.000000
# Epoch 6, Train Loss: 0.035319, Train Acc: 98.623279, Val Loss: inf, Val Acc: 90.500000
# Epoch 7, Train Loss: 0.019045, Train Acc: 99.499374, Val Loss: inf, Val Acc: 84.500000
# Epoch 8, Train Loss: 0.012340, Train Acc: 99.624531, Val Loss: inf, Val Acc: 87.500000
# Epoch 9, Train Loss: 0.009866, Train Acc: 99.624531, Val Loss: inf, Val Acc: 77.500000
# Epoch 10, Train Loss: 0.006411, Train Acc: 100.000000, Val Loss: 1.385324, Val Acc: 83.000000
# Epoch 11, Train Loss: 0.003320, Train Acc: 100.000000, Val Loss: 1.460407, Val Acc: 73.000000
# Epoch 12, Train Loss: 0.002823, Train Acc: 100.000000, Val Loss: 0.141014, Val Acc: 95.000000
# Epoch 13, Train Loss: 0.001578, Train Acc: 100.000000, Val Loss: inf, Val Acc: 98.000000
# Epoch 14, Train Loss: 0.001306, Train Acc: 100.000000, Val Loss: inf, Val Acc: 98.500000
# Epoch 15, Train Loss: 0.000829, Train Acc: 100.000000, Val Loss: inf, Val Acc: 96.000000
# Epoch 16, Train Loss: 0.000677, Train Acc: 100.000000, Val Loss: 0.813914, Val Acc: 96.500000
# Epoch 17, Train Loss: 0.000610, Train Acc: 100.000000, Val Loss: 0.296859, Val Acc: 96.000000
# Epoch 18, Train Loss: 0.000731, Train Acc: 100.000000, Val Loss: 0.160104, Val Acc: 96.000000
# Epoch 19, Train Loss: 0.000663, Train Acc: 100.000000, Val Loss: 0.048204, Val Acc: 99.000000
# Epoch 20, Train Loss: 0.000619, Train Acc: 100.000000, Val Loss: 0.116870, Val Acc: 97.500000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.421831, Train Acc: 74.843554, Val Loss: inf, Val Acc: 40.500000
# Epoch 2, Train Loss: 0.151282, Train Acc: 93.617021, Val Loss: 0.620856, Val Acc: 79.000000
# Epoch 3, Train Loss: 0.102736, Train Acc: 94.868586, Val Loss: 0.524738, Val Acc: 84.000000
# Epoch 4, Train Loss: 0.063749, Train Acc: 97.622028, Val Loss: 0.478307, Val Acc: 88.500000
# Epoch 5, Train Loss: 0.039526, Train Acc: 98.372966, Val Loss: 0.266793, Val Acc: 92.000000
# Epoch 6, Train Loss: 0.022847, Train Acc: 99.624531, Val Loss: 0.253258, Val Acc: 93.000000
# Epoch 7, Train Loss: 0.012447, Train Acc: 99.749687, Val Loss: 0.218992, Val Acc: 95.500000
# Epoch 8, Train Loss: 0.008338, Train Acc: 100.000000, Val Loss: 0.142936, Val Acc: 96.500000
# Epoch 9, Train Loss: 0.004643, Train Acc: 100.000000, Val Loss: 0.377283, Val Acc: 95.000000
# Epoch 10, Train Loss: 0.003190, Train Acc: 100.000000, Val Loss: inf, Val Acc: 93.000000
# Epoch 11, Train Loss: 0.001631, Train Acc: 100.000000, Val Loss: 1.046974, Val Acc: 92.500000
# Epoch 12, Train Loss: 0.002394, Train Acc: 99.874844, Val Loss: inf, Val Acc: 91.500000
# Epoch 13, Train Loss: 0.002013, Train Acc: 100.000000, Val Loss: inf, Val Acc: 88.000000
# Epoch 14, Train Loss: 0.001404, Train Acc: 100.000000, Val Loss: inf, Val Acc: 88.000000
# Epoch 15, Train Loss: 0.000909, Train Acc: 100.000000, Val Loss: inf, Val Acc: 86.500000
# Epoch 16, Train Loss: 0.000869, Train Acc: 100.000000, Val Loss: inf, Val Acc: 84.500000
# Epoch 17, Train Loss: 0.000794, Train Acc: 100.000000, Val Loss: inf, Val Acc: 84.000000
# Epoch 18, Train Loss: 0.000650, Train Acc: 100.000000, Val Loss: inf, Val Acc: 83.500000
# Epoch 19, Train Loss: 0.000627, Train Acc: 100.000000, Val Loss: inf, Val Acc: 83.500000
# Epoch 20, Train Loss: 0.000564, Train Acc: 100.000000, Val Loss: inf, Val Acc: 83.000000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.440188, Train Acc: 73.466834, Val Loss: inf, Val Acc: 64.000000
# Epoch 2, Train Loss: 0.195626, Train Acc: 89.111389, Val Loss: 0.314796, Val Acc: 86.500000
# Epoch 3, Train Loss: 0.107782, Train Acc: 94.993742, Val Loss: 0.188159, Val Acc: 93.000000
# Epoch 4, Train Loss: 0.067488, Train Acc: 97.246558, Val Loss: inf, Val Acc: 36.000000
# Epoch 5, Train Loss: 0.036734, Train Acc: 98.498123, Val Loss: 0.121679, Val Acc: 95.000000
# Epoch 6, Train Loss: 0.021675, Train Acc: 99.499374, Val Loss: 0.074659, Val Acc: 98.500000
# Epoch 7, Train Loss: 0.016061, Train Acc: 99.499374, Val Loss: 0.081791, Val Acc: 97.000000
# Epoch 8, Train Loss: 0.008444, Train Acc: 99.749687, Val Loss: 0.061899, Val Acc: 97.000000
# Epoch 9, Train Loss: 0.005066, Train Acc: 100.000000, Val Loss: 0.074451, Val Acc: 97.500000
# Epoch 10, Train Loss: 0.004287, Train Acc: 99.874844, Val Loss: 0.068360, Val Acc: 98.500000
# Epoch 11, Train Loss: 0.002107, Train Acc: 100.000000, Val Loss: 0.076988, Val Acc: 97.500000
# Epoch 12, Train Loss: 0.001545, Train Acc: 100.000000, Val Loss: 0.079636, Val Acc: 96.500000
# Epoch 13, Train Loss: 0.001464, Train Acc: 100.000000, Val Loss: 0.106616, Val Acc: 95.000000
# Epoch 14, Train Loss: 0.000720, Train Acc: 100.000000, Val Loss: 0.122861, Val Acc: 95.500000
# Epoch 15, Train Loss: 0.000875, Train Acc: 100.000000, Val Loss: 0.115881, Val Acc: 96.000000
# Epoch 16, Train Loss: 0.000981, Train Acc: 100.000000, Val Loss: 0.098699, Val Acc: 95.500000
# Epoch 17, Train Loss: 0.000738, Train Acc: 100.000000, Val Loss: 0.079684, Val Acc: 96.500000
# Epoch 18, Train Loss: 0.000450, Train Acc: 100.000000, Val Loss: 0.059570, Val Acc: 97.500000
# Epoch 19, Train Loss: 0.000732, Train Acc: 100.000000, Val Loss: 0.054988, Val Acc: 98.000000
# Epoch 20, Train Loss: 0.000498, Train Acc: 100.000000, Val Loss: 0.053851, Val Acc: 97.500000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.407407, Train Acc: 77.471840, Val Loss: inf, Val Acc: 64.000000
# Epoch 2, Train Loss: 0.206559, Train Acc: 89.361702, Val Loss: inf, Val Acc: 55.500000
# Epoch 3, Train Loss: 0.122092, Train Acc: 94.993742, Val Loss: 0.531619, Val Acc: 84.500000
# Epoch 4, Train Loss: 0.071750, Train Acc: 96.745932, Val Loss: 0.205356, Val Acc: 93.500000
# Epoch 5, Train Loss: 0.058912, Train Acc: 97.246558, Val Loss: 0.225327, Val Acc: 93.500000
# Epoch 6, Train Loss: 0.028666, Train Acc: 98.873592, Val Loss: 0.495561, Val Acc: 84.500000
# Epoch 7, Train Loss: 0.018937, Train Acc: 99.624531, Val Loss: 0.113766, Val Acc: 96.000000
# Epoch 8, Train Loss: 0.013191, Train Acc: 99.874844, Val Loss: 0.117793, Val Acc: 97.000000
# Epoch 9, Train Loss: 0.008895, Train Acc: 99.874844, Val Loss: 0.156869, Val Acc: 96.500000
# Epoch 10, Train Loss: 0.005454, Train Acc: 100.000000, Val Loss: 0.158099, Val Acc: 97.000000
# Epoch 11, Train Loss: 0.004481, Train Acc: 99.874844, Val Loss: 0.135556, Val Acc: 96.500000
# Epoch 12, Train Loss: 0.005368, Train Acc: 99.749687, Val Loss: 0.117527, Val Acc: 98.000000
# Epoch 13, Train Loss: 0.002762, Train Acc: 99.874844, Val Loss: 0.135992, Val Acc: 98.500000
# Epoch 14, Train Loss: 0.001283, Train Acc: 100.000000, Val Loss: 0.141420, Val Acc: 97.000000
# Epoch 15, Train Loss: 0.002141, Train Acc: 100.000000, Val Loss: 0.117118, Val Acc: 98.000000
# Epoch 16, Train Loss: 0.001479, Train Acc: 100.000000, Val Loss: 0.139599, Val Acc: 97.000000
# Epoch 17, Train Loss: 0.001289, Train Acc: 100.000000, Val Loss: 0.160113, Val Acc: 96.500000
# Epoch 18, Train Loss: 0.001268, Train Acc: 100.000000, Val Loss: 0.172499, Val Acc: 98.000000
# Epoch 19, Train Loss: 0.000881, Train Acc: 100.000000, Val Loss: 0.135187, Val Acc: 97.500000
# Epoch 20, Train Loss: 0.000914, Train Acc: 100.000000, Val Loss: 0.111898, Val Acc: 97.500000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.344571, Train Acc: 78.473091, Val Loss: inf, Val Acc: 64.000000
# Epoch 2, Train Loss: 0.140306, Train Acc: 92.991239, Val Loss: 0.962840, Val Acc: 76.000000
# Epoch 3, Train Loss: 0.087350, Train Acc: 95.869837, Val Loss: 0.544538, Val Acc: 86.000000
# Epoch 4, Train Loss: 0.052975, Train Acc: 97.371715, Val Loss: 0.390649, Val Acc: 89.000000
# Epoch 5, Train Loss: 0.030967, Train Acc: 98.873592, Val Loss: 0.261248, Val Acc: 91.000000
# Epoch 6, Train Loss: 0.016153, Train Acc: 99.499374, Val Loss: 0.145575, Val Acc: 92.500000
# Epoch 7, Train Loss: 0.009449, Train Acc: 99.624531, Val Loss: 0.100681, Val Acc: 95.500000
# Epoch 8, Train Loss: 0.005238, Train Acc: 99.874844, Val Loss: 0.084306, Val Acc: 96.500000
# Epoch 9, Train Loss: 0.006163, Train Acc: 99.874844, Val Loss: 0.090078, Val Acc: 97.000000
# Epoch 10, Train Loss: 0.002388, Train Acc: 100.000000, Val Loss: 0.127283, Val Acc: 94.500000
# Epoch 11, Train Loss: 0.004265, Train Acc: 99.874844, Val Loss: 0.081981, Val Acc: 97.000000
# Epoch 12, Train Loss: 0.001849, Train Acc: 100.000000, Val Loss: 0.078934, Val Acc: 96.500000
# Epoch 13, Train Loss: 0.002168, Train Acc: 100.000000, Val Loss: 0.101852, Val Acc: 96.500000
# Epoch 14, Train Loss: 0.001346, Train Acc: 100.000000, Val Loss: 0.076485, Val Acc: 98.000000
# Epoch 15, Train Loss: 0.001335, Train Acc: 100.000000, Val Loss: 0.087870, Val Acc: 96.500000
# Epoch 16, Train Loss: 0.000617, Train Acc: 100.000000, Val Loss: 0.081548, Val Acc: 97.500000
# Epoch 17, Train Loss: 0.000531, Train Acc: 100.000000, Val Loss: 0.090445, Val Acc: 97.000000
# Epoch 18, Train Loss: 0.000702, Train Acc: 100.000000, Val Loss: 0.377197, Val Acc: 90.500000
# Epoch 19, Train Loss: 0.000676, Train Acc: 100.000000, Val Loss: 0.116067, Val Acc: 96.500000
# Epoch 20, Train Loss: 0.000278, Train Acc: 100.000000, Val Loss: 0.091305, Val Acc: 96.500000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.411863, Train Acc: 78.848561, Val Loss: inf, Val Acc: 64.000000
# Epoch 2, Train Loss: 0.194878, Train Acc: 92.740926, Val Loss: inf, Val Acc: 64.000000
# Epoch 3, Train Loss: 0.103270, Train Acc: 94.993742, Val Loss: 0.409477, Val Acc: 89.000000
# Epoch 4, Train Loss: 0.068309, Train Acc: 96.996245, Val Loss: 0.260644, Val Acc: 92.000000
# Epoch 5, Train Loss: 0.042310, Train Acc: 97.872340, Val Loss: 0.197088, Val Acc: 93.500000
# Epoch 6, Train Loss: 0.025304, Train Acc: 99.249061, Val Loss: 0.109691, Val Acc: 96.000000
# Epoch 7, Train Loss: 0.014206, Train Acc: 99.624531, Val Loss: 0.075212, Val Acc: 97.000000
# Epoch 8, Train Loss: 0.009588, Train Acc: 99.874844, Val Loss: 0.068527, Val Acc: 97.000000
# Epoch 9, Train Loss: 0.005474, Train Acc: 99.874844, Val Loss: 0.072713, Val Acc: 97.500000
# Epoch 10, Train Loss: 0.004776, Train Acc: 99.874844, Val Loss: 0.055851, Val Acc: 98.000000
# Epoch 11, Train Loss: 0.001938, Train Acc: 100.000000, Val Loss: 0.028425, Val Acc: 99.000000
# Epoch 12, Train Loss: 0.003521, Train Acc: 99.874844, Val Loss: 0.073201, Val Acc: 96.000000
# Epoch 13, Train Loss: 0.001942, Train Acc: 100.000000, Val Loss: 0.066191, Val Acc: 97.000000
# Epoch 14, Train Loss: 0.000958, Train Acc: 100.000000, Val Loss: 0.050997, Val Acc: 98.500000
# Epoch 15, Train Loss: 0.000928, Train Acc: 100.000000, Val Loss: 0.032562, Val Acc: 98.500000
# Epoch 16, Train Loss: 0.000798, Train Acc: 100.000000, Val Loss: 0.046076, Val Acc: 98.000000
# Epoch 17, Train Loss: 0.000497, Train Acc: 100.000000, Val Loss: 0.045097, Val Acc: 98.000000
# Epoch 18, Train Loss: 0.000569, Train Acc: 100.000000, Val Loss: 0.048433, Val Acc: 98.000000
# Epoch 19, Train Loss: 0.000504, Train Acc: 100.000000, Val Loss: 0.042577, Val Acc: 98.000000
# Epoch 20, Train Loss: 0.000336, Train Acc: 100.000000, Val Loss: 0.045892, Val Acc: 98.000000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.520247, Train Acc: 67.709637, Val Loss: 13.493169, Val Acc: 37.000000
# Epoch 2, Train Loss: 0.193173, Train Acc: 92.240300, Val Loss: 2.420095, Val Acc: 45.000000
# Epoch 3, Train Loss: 0.112305, Train Acc: 95.369212, Val Loss: 1.106619, Val Acc: 65.000000
# Epoch 4, Train Loss: 0.073558, Train Acc: 96.370463, Val Loss: 0.687864, Val Acc: 79.500000
# Epoch 5, Train Loss: 0.039818, Train Acc: 98.372966, Val Loss: 0.427825, Val Acc: 86.500000
# Epoch 6, Train Loss: 0.027781, Train Acc: 98.873592, Val Loss: 0.159461, Val Acc: 93.000000
# Epoch 7, Train Loss: 0.020471, Train Acc: 98.873592, Val Loss: 0.110459, Val Acc: 96.500000
# Epoch 8, Train Loss: 0.009404, Train Acc: 99.874844, Val Loss: 0.101970, Val Acc: 96.500000
# Epoch 9, Train Loss: 0.007445, Train Acc: 99.874844, Val Loss: 0.081301, Val Acc: 97.000000
# Epoch 10, Train Loss: 0.005056, Train Acc: 99.874844, Val Loss: 0.096533, Val Acc: 96.000000
# Epoch 11, Train Loss: 0.003233, Train Acc: 100.000000, Val Loss: 0.116639, Val Acc: 95.500000
# Epoch 12, Train Loss: 0.002648, Train Acc: 100.000000, Val Loss: 0.162823, Val Acc: 96.000000
# Epoch 13, Train Loss: 0.002175, Train Acc: 100.000000, Val Loss: 0.500768, Val Acc: 91.000000
# Epoch 14, Train Loss: 0.002042, Train Acc: 100.000000, Val Loss: 1.281724, Val Acc: 83.000000
# Epoch 15, Train Loss: 0.001203, Train Acc: 100.000000, Val Loss: 3.642808, Val Acc: 75.000000
# Epoch 16, Train Loss: 0.001170, Train Acc: 100.000000, Val Loss: 9.130242, Val Acc: 66.000000
# Epoch 17, Train Loss: 0.001167, Train Acc: 100.000000, Val Loss: inf, Val Acc: 64.500000
# Epoch 18, Train Loss: 0.001049, Train Acc: 100.000000, Val Loss: inf, Val Acc: 64.000000
# Epoch 19, Train Loss: 0.000849, Train Acc: 100.000000, Val Loss: inf, Val Acc: 64.000000
# Epoch 20, Train Loss: 0.000741, Train Acc: 100.000000, Val Loss: inf, Val Acc: 64.000000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.368327, Train Acc: 79.474343, Val Loss: inf, Val Acc: 38.500000
# Epoch 2, Train Loss: 0.166076, Train Acc: 91.364205, Val Loss: inf, Val Acc: 64.000000
# Epoch 3, Train Loss: 0.082926, Train Acc: 96.245307, Val Loss: inf, Val Acc: 39.500000
# Epoch 4, Train Loss: 0.049214, Train Acc: 98.122653, Val Loss: 0.247701, Val Acc: 91.000000
# Epoch 5, Train Loss: 0.028939, Train Acc: 98.748436, Val Loss: 1.213306, Val Acc: 81.000000
# Epoch 6, Train Loss: 0.020137, Train Acc: 99.249061, Val Loss: 0.138354, Val Acc: 94.500000
# Epoch 7, Train Loss: 0.012985, Train Acc: 99.374218, Val Loss: 0.098559, Val Acc: 97.000000
# Epoch 8, Train Loss: 0.004734, Train Acc: 99.874844, Val Loss: 0.116416, Val Acc: 97.000000
# Epoch 9, Train Loss: 0.007368, Train Acc: 99.749687, Val Loss: 0.055338, Val Acc: 98.500000
# Epoch 10, Train Loss: 0.003091, Train Acc: 100.000000, Val Loss: 0.088163, Val Acc: 98.000000
# Epoch 11, Train Loss: 0.004209, Train Acc: 99.874844, Val Loss: 0.052215, Val Acc: 99.000000
# Epoch 12, Train Loss: 0.001545, Train Acc: 100.000000, Val Loss: 0.042029, Val Acc: 98.500000
# Epoch 13, Train Loss: 0.002462, Train Acc: 100.000000, Val Loss: 0.041254, Val Acc: 98.500000
# Epoch 14, Train Loss: 0.001568, Train Acc: 100.000000, Val Loss: 0.044850, Val Acc: 99.000000
# Epoch 15, Train Loss: 0.001136, Train Acc: 100.000000, Val Loss: 0.033831, Val Acc: 99.000000
# Epoch 16, Train Loss: 0.000706, Train Acc: 100.000000, Val Loss: 0.045067, Val Acc: 99.000000
# Epoch 17, Train Loss: 0.000554, Train Acc: 100.000000, Val Loss: 0.300755, Val Acc: 98.000000
# Epoch 18, Train Loss: 0.000682, Train Acc: 100.000000, Val Loss: 0.131118, Val Acc: 97.500000
# Epoch 19, Train Loss: 0.000547, Train Acc: 100.000000, Val Loss: inf, Val Acc: 98.000000
# Epoch 20, Train Loss: 0.000365, Train Acc: 100.000000, Val Loss: inf, Val Acc: 97.000000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.436675, Train Acc: 76.095119, Val Loss: inf, Val Acc: 64.000000
# Epoch 2, Train Loss: 0.180647, Train Acc: 93.241552, Val Loss: 0.795253, Val Acc: 75.000000
# Epoch 3, Train Loss: 0.099439, Train Acc: 95.744681, Val Loss: 0.653005, Val Acc: 82.000000
# Epoch 4, Train Loss: 0.069890, Train Acc: 96.370463, Val Loss: 0.335298, Val Acc: 91.000000
# Epoch 5, Train Loss: 0.039729, Train Acc: 98.247810, Val Loss: 0.185217, Val Acc: 93.000000
# Epoch 6, Train Loss: 0.024717, Train Acc: 99.123905, Val Loss: 0.125675, Val Acc: 95.500000
# Epoch 7, Train Loss: 0.016036, Train Acc: 99.624531, Val Loss: 0.141448, Val Acc: 96.000000
# Epoch 8, Train Loss: 0.009684, Train Acc: 99.624531, Val Loss: 0.128834, Val Acc: 95.500000
# Epoch 9, Train Loss: 0.006796, Train Acc: 99.874844, Val Loss: 0.100162, Val Acc: 96.000000
# Epoch 10, Train Loss: 0.004043, Train Acc: 100.000000, Val Loss: 0.090429, Val Acc: 96.500000
# Epoch 11, Train Loss: 0.003198, Train Acc: 100.000000, Val Loss: 0.101640, Val Acc: 97.000000
# Epoch 12, Train Loss: 0.001927, Train Acc: 100.000000, Val Loss: 0.093283, Val Acc: 97.000000
# Epoch 13, Train Loss: 0.001673, Train Acc: 100.000000, Val Loss: 0.106876, Val Acc: 96.500000
# Epoch 14, Train Loss: 0.001285, Train Acc: 100.000000, Val Loss: 0.100224, Val Acc: 97.000000
# Epoch 15, Train Loss: 0.001230, Train Acc: 100.000000, Val Loss: 0.112909, Val Acc: 97.000000
# Epoch 16, Train Loss: 0.000927, Train Acc: 100.000000, Val Loss: 0.131030, Val Acc: 97.000000
# Epoch 17, Train Loss: 0.000824, Train Acc: 100.000000, Val Loss: 0.191609, Val Acc: 96.000000
# Epoch 18, Train Loss: 0.000640, Train Acc: 100.000000, Val Loss: 0.104753, Val Acc: 97.000000
# Epoch 19, Train Loss: 0.000702, Train Acc: 100.000000, Val Loss: 0.249494, Val Acc: 97.000000
# Epoch 20, Train Loss: 0.000736, Train Acc: 100.000000, Val Loss: 0.251475, Val Acc: 96.000000
# Model:test_high_correlation
# Epoch 1, Train Loss: 0.423491, Train Acc: 73.591990, Val Loss: inf, Val Acc: 64.000000
# Epoch 2, Train Loss: 0.184641, Train Acc: 91.364205, Val Loss: 0.937174, Val Acc: 68.000000
# Epoch 3, Train Loss: 0.108395, Train Acc: 94.868586, Val Loss: 1.234227, Val Acc: 72.000000
# Epoch 4, Train Loss: 0.068757, Train Acc: 97.246558, Val Loss: 0.815316, Val Acc: 80.500000
# Epoch 5, Train Loss: 0.046272, Train Acc: 97.747184, Val Loss: 0.393206, Val Acc: 91.000000
# Epoch 6, Train Loss: 0.032184, Train Acc: 98.122653, Val Loss: 0.334072, Val Acc: 91.500000
# Epoch 7, Train Loss: 0.020844, Train Acc: 99.374218, Val Loss: 0.280111, Val Acc: 93.500000
# Epoch 8, Train Loss: 0.009425, Train Acc: 99.874844, Val Loss: 0.181054, Val Acc: 96.000000
# Epoch 9, Train Loss: 0.009853, Train Acc: 99.499374, Val Loss: 0.122675, Val Acc: 97.500000
# Epoch 10, Train Loss: 0.005877, Train Acc: 100.000000, Val Loss: 0.134790, Val Acc: 96.500000
# Epoch 11, Train Loss: 0.003679, Train Acc: 99.874844, Val Loss: 0.146830, Val Acc: 96.500000
# Epoch 12, Train Loss: 0.003018, Train Acc: 100.000000, Val Loss: 0.118851, Val Acc: 96.000000
# Epoch 13, Train Loss: 0.002094, Train Acc: 100.000000, Val Loss: 0.125451, Val Acc: 97.500000
# Epoch 14, Train Loss: 0.001337, Train Acc: 100.000000, Val Loss: 0.120046, Val Acc: 97.000000
# Epoch 15, Train Loss: 0.001051, Train Acc: 100.000000, Val Loss: 0.106623, Val Acc: 96.500000
# Epoch 16, Train Loss: 0.000825, Train Acc: 100.000000, Val Loss: 0.135100, Val Acc: 97.500000
# Epoch 17, Train Loss: 0.000657, Train Acc: 100.000000, Val Loss: 0.117025, Val Acc: 97.500000
# Epoch 18, Train Loss: 0.000798, Train Acc: 100.000000, Val Loss: 0.112195, Val Acc: 97.000000
# Epoch 19, Train Loss: 0.001222, Train Acc: 100.000000, Val Loss: 0.104822, Val Acc: 97.000000
# Epoch 20, Train Loss: 0.000371, Train Acc: 100.000000, Val Loss: 0.105498, Val Acc: 98.500000
# Finished!
#  Acc:(92.55, 98.5),
#  list:[97.5, 83.0, 97.5, 97.5, 96.5, 98.0, 64.0, 97.0, 96.0, 98.5]
